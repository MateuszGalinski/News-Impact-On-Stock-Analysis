# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.graph_objects as go

# %% [markdown]
# ## Data loading

# %%
nvidia_news = pd.read_csv("../data/data_gnews_api/nvidia_news.csv")
nvidia_news.head(2)
# Out:
#            published_at                                              title  \
# 0  2020-01-07T14:33:08Z  TiVo Stream 4K uses Android TV, announced at C...
# 1  2020-01-09T18:48:47Z         Every new Android TV announced at CES 2020
#
#                                          description  \
# 0  TiVo Stream 4K was officially announced at CES...
# 1  Just like any year, this year's CES has focuse...
#
#                                              content  \
# 0  CES 2020 rolls on this morning as TiVo has unv...
# 1  Just like any year, this year's CES has focuse...
#
#                                                  url     source_name  \
# 0  https://9to5toys.com/2020/01/07/tivo-stream-4k...        9to5Toys
# 1  https://www.androidpolice.com/2020/01/09/every...  Android Police
#
#                       source_url  \
# 0           https://9to5toys.com
# 1  https://www.androidpolice.com
#
#                                            image_url           query  \
# ...

# %%
nvidia_news.iloc[0]["content"]
# Out:
# 'CES 2020 rolls on this morning as TiVo has unveiled its latest creation, the TiVo Stream 4K. While everyone knows the brand for its popular DVRs, today, we see a departure from the set-top box for a new dongle design. Not only is TiVo making a switch to stay in line with Roku and Amazon’s streamers, they are dropping the price as well. The new TiVo Stream 4K will retail for a fraction of the cost of its previously-released products. Head below for more. TiVo Stream 4K unveiled at CES 2020 TiVo is known for its DVRs, without a doubt, but the new TiVo Stream 4K departs with a focus on streaming content instead. It’s backed by Android TV and is made to work with the popular Sling TV streaming service. As you’d guess in 2020, TiVo Stream 4K is based around the cloud, leaning on Sling TV to deliver DVR functionality and more. However, if you’re already in the TiVo ecosystem, don’t expect to beam your recorded content to this dongle. TiVo Stream 4K is not compatible with existing hardware
# ...

# %%
nvidia_news['published_at'] = pd.to_datetime(nvidia_news['published_at'], format="ISO8601", utc=True)
nvidia_news['published_at'].dtype
# Out:
# datetime64[us, UTC]

# %%
print(nvidia_news['published_at'].min())
print(nvidia_news['published_at'].max())
# Out:
# 2020-01-07 14:33:08+00:00
# 2026-05-17 16:00:02+00:00
